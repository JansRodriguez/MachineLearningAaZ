# %% [markdown]
# ### 2.1 Base de Dados
# BASE DO CENSO

# %% [markdown]
# ##### 1. Importação  das bibliotecas básicas

# %%
import plotly
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
dados_censo = pd.read_csv("Machine Learning e Data Science com Python de A à Z-20230126T194647Z-001\Bases de dados\census.csv")
dados_censo
# Out:
#        age          workclass  final-weight    education  education-num  \
# 0       39          State-gov         77516    Bachelors             13
# 1       50   Self-emp-not-inc         83311    Bachelors             13
# 2       38            Private        215646      HS-grad              9
# 3       53            Private        234721         11th              7
# 4       28            Private        338409    Bachelors             13
# ...    ...                ...           ...          ...            ...
# 32556   27            Private        257302   Assoc-acdm             12
# 32557   40            Private        154374      HS-grad              9
# 32558   58            Private        151910      HS-grad              9
# 32559   22            Private        201490      HS-grad              9
# 32560   52       Self-emp-inc        287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# ...

# %%
dados_censo.describe()
# Out:
#                 age  final-weight  education-num  capital-gain  capital-loos  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hour-per-week
# count   32561.000000
# mean       40.437456
# std        12.347429
# min         1.000000
# 25%        40.000000
# 50%        40.000000
# 75%        45.000000
# max        99.000000

# %%
dados_censo['race'].value_counts()
# Out:
#  White                 27816
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: race, dtype: int64

# %%
dados_censo['income'].value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: income, dtype: int64

# %%
## VERIFICAÇÃO DE VALORES FALTANTES
dados_censo.isnull().sum()
# Out:
# age               0
# workclass         0
# final-weight      0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loos      0
# hour-per-week     0
# native-country    0
# income            0
# dtype: int64

# %% [markdown]
# #### 2. Visualização de Dados

# %%
np.unique(dados_censo['income'], return_counts=True)
# Out:
# (array([' <=50K', ' >50K'], dtype=object), array([24720,  7841], dtype=int64))

# %% [markdown]
# ##### INSIGHTS INICIAIS SOBRE OS DADOS

# %%
sns.countplot(y=dados_censo['income'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='income'>

# %%
plt.hist(x=dados_censo['age']);

# %%
plt.hist(x=dados_censo['education-num']);

# %%
plt.hist(dados_censo['hour-per-week']);

# %% [markdown]
# ##### INSIGHTS MAIS APROFUNDADOS

# %%
grafico = px.treemap(dados_censo, path=['workclass', 'age'])
grafico.show()

# %%
graficoOcupation = px.treemap(dados_censo, path=['occupation', 'relationship', 'age'])
graficoOcupation.show()
